# %%
import json
import requests
from config import api_key

# %%
# Where USD is the base currency you want to use
url = "https://v6.exchangerate-api.com/v6/ce18d1a494ccde79d7def53a/pair/USD/MXN/2"
url2 = "https://v6.exchangerate-api.com/v6/ce18d1a494ccde79d7def53a/latest/USD"
url3 = "https://v6.exchangerate-api.com/v6/ce18d1a494ccde79d7def53a/pair/USD/MXN"

convert_from = input("Convert From")
convert_to = input("Convert To")
amount = input("Amount")

# Making our request
response = requests.get(url)
ustomexusd = response.json()

response2 = requests.get(url2)
latest = response2.json()

pair = requests.get(url3)
paired = pair.json()
# Out:
# Convert From USD
# Convert To EUR
# Amount 20

# %%
latest
# Out:
# {'result': 'success',
#  'documentation': 'https://www.exchangerate-api.com/docs',
#  'terms_of_use': 'https://www.exchangerate-api.com/terms',
#  'time_last_update_unix': 1658966401,
#  'time_last_update_utc': 'Thu, 28 Jul 2022 00:00:01 +0000',
#  'time_next_update_unix': 1659052801,
#  'time_next_update_utc': 'Fri, 29 Jul 2022 00:00:01 +0000',
#  'base_code': 'USD',
#  'conversion_rates': {'USD': 1,
#   'AED': 3.6725,
#   'AFN': 90.1301,
#   'ALL': 114.3549,
#   'AMD': 406.0653,
#   'ANG': 1.79,
#   'AOA': 430.9872,
#   'ARS': 130.0631,
#   'AUD': 1.4358,
#   'AWG': 1.79,
#   'AZN': 1.6931,
#   'BAM': 1.9252,
#   'BBD': 2.0,
#   'BDT': 93.9733,
#   'BGN': 1.9254,
#   'BHD': 0.376,
#   'BIF': 2038.5349,
#   'BMD': 1.0,
#   'BND': 1.3859,
#   'BOB': 6.8441,
#   'BRL': 5.3261,
#   'BSD': 1.0,
#   'BTN': 79.8035,
#   'BWP': 12.6839,
#   'BYN': 2.995,
#   'BZD': 2.0,
#   'CAD': 1.2849,
#   'CDF': 1992.3467,
#   'CHF': 0.9611,
#   'CLP': 924.7318,
#   'CNY': 6.7518,
# ...

# %%
ustomexusd
# Out:
# {'result': 'success',
#  'documentation': 'https://www.exchangerate-api.com/docs',
#  'terms_of_use': 'https://www.exchangerate-api.com/terms',
#  'time_last_update_unix': 1658966401,
#  'time_last_update_utc': 'Thu, 28 Jul 2022 00:00:01 +0000',
#  'time_next_update_unix': 1659052801,
#  'time_next_update_utc': 'Fri, 29 Jul 2022 00:00:01 +0000',
#  'base_code': 'USD',
#  'target_code': 'MXN',
#  'conversion_rate': 20.401,
#  'conversion_result': 40.802}

# %%
paired
# Out:
# {'result': 'success',
#  'documentation': 'https://www.exchangerate-api.com/docs',
#  'terms_of_use': 'https://www.exchangerate-api.com/terms',
#  'time_last_update_unix': 1658966401,
#  'time_last_update_utc': 'Thu, 28 Jul 2022 00:00:01 +0000',
#  'time_next_update_unix': 1659052801,
#  'time_next_update_utc': 'Fri, 29 Jul 2022 00:00:01 +0000',
#  'base_code': 'USD',
#  'target_code': 'MXN',
#  'conversion_rate': 20.401}

# %%
# Out:
# [{'MapDate': '20220712',
#   'AreaOfInterest': 'Total',
#   'None': '1,271,894.10',
#   'D0': '2,327,857.05',
#   'D1': '1,619,031.62',
#   'D2': '978,688.38',
#   'D3': '517,465.69',
#   'D4': '140,332.97',
#   'ValidStart': '2022-07-12',
#   'ValidEnd': '2022-07-18',
#   'StatisticFormatID': '1'},
#  {'MapDate': '20220705',
#   'AreaOfInterest': 'Total',
#   'None': '1,221,173.73',
#   'D0': '2,378,577.42',
#   'D1': '1,594,726.68',
#   'D2': '992,482.87',
#   'D3': '530,574.94',
#   'D4': '115,908.59',
#   'ValidStart': '2022-07-05',
#   'ValidEnd': '2022-07-11',
#   'StatisticFormatID': '1'},
#  {'MapDate': '20220628',
#   'AreaOfInterest': 'Total',
#   'None': '1,258,894.09',
#   'D0': '2,340,857.06',
#   'D1': '1,530,854.96',
#   'D2': '993,635.26',
#   'D3': '528,615.28',
#   'D4': '116,398.26',
#   'ValidStart': '2022-06-28',
#   'ValidEnd': '2022-07-04',
#   'StatisticFormatID': '1'},
#  {'MapDate': '20220621',
#   'AreaOfInterest': 'Total',
#   'None': '1,446,327.21',
# ...
